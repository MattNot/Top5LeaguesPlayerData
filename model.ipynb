# %%
import pandas as pd
import os
import numpy as np
os.environ['KERAS_BACKEND'] = 'torch'
# import keras

# %%
def findCorrelation(corr, cutoff=0.9, exact=None):
    """
    This function is the Python implementation of the R function 
    `findCorrelation()`.
    
    Relies on numpy and pandas, so must have them pre-installed.
    
    It searches through a correlation matrix and returns a list of column names 
    to remove to reduce pairwise correlations.
    
    For the documentation of the R function, see 
    https://www.rdocumentation.org/packages/caret/topics/findCorrelation
    and for the source code of `findCorrelation()`, see
    https://github.com/topepo/caret/blob/master/pkg/caret/R/findCorrelation.R
    
    -----------------------------------------------------------------------------

    Parameters:
    -----------
    corr: pandas dataframe.
        A correlation matrix as a pandas dataframe.
    cutoff: float, default: 0.9.
        A numeric value for the pairwise absolute correlation cutoff
    exact: bool, default: None
        A boolean value that determines whether the average correlations be 
        recomputed at each step
    -----------------------------------------------------------------------------
    Returns:
    --------
    list of column names
    -----------------------------------------------------------------------------
    Example:
    --------
    R1 = pd.DataFrame({
        'x1': [1.0, 0.86, 0.56, 0.32, 0.85],
        'x2': [0.86, 1.0, 0.01, 0.74, 0.32],
        'x3': [0.56, 0.01, 1.0, 0.65, 0.91],
        'x4': [0.32, 0.74, 0.65, 1.0, 0.36],
        'x5': [0.85, 0.32, 0.91, 0.36, 1.0]
    }, index=['x1', 'x2', 'x3', 'x4', 'x5'])

    findCorrelation(R1, cutoff=0.6, exact=False)  # ['x4', 'x5', 'x1', 'x3']
    findCorrelation(R1, cutoff=0.6, exact=True)   # ['x1', 'x5', 'x4'] 
    """
    
    def _findCorrelation_fast(corr, avg, cutoff):

        combsAboveCutoff = corr.where(lambda x: (np.tril(x)==0) & (x > cutoff)).stack().index

        rowsToCheck = combsAboveCutoff.get_level_values(0)
        colsToCheck = combsAboveCutoff.get_level_values(1)

        msk = avg[colsToCheck] > avg[rowsToCheck].values
        deletecol = pd.unique(np.r_[colsToCheck[msk], rowsToCheck[~msk]]).tolist()

        return deletecol


    def _findCorrelation_exact(corr, avg, cutoff):

        x = corr.loc[(*[avg.sort_values(ascending=False).index]*2,)]

        if (x.dtypes.values[:, None] == ['int64', 'int32', 'int16', 'int8']).any():
            x = x.astype(float)

        x.values[(*[np.arange(len(x))]*2,)] = np.nan

        deletecol = []
        for ix, i in enumerate(x.columns[:-1]):
            for j in x.columns[ix+1:]:
                if x.loc[i, j] > cutoff:
                    if x[i].mean() > x[j].mean():
                        deletecol.append(i)
                        x.loc[i] = x[i] = np.nan
                    else:
                        deletecol.append(j)
                        x.loc[j] = x[j] = np.nan
        return deletecol

    
    if not np.allclose(corr, corr.T) or any(corr.columns!=corr.index):
        raise ValueError("correlation matrix is not symmetric.")
        
    acorr = corr.abs()
    avg = acorr.mean()
        
    if exact or exact is None and corr.shape[1]<100:
        return _findCorrelation_exact(acorr, avg, cutoff)
    else:
        return _findCorrelation_fast(acorr, avg, cutoff)

# %%
# for file in os.listdir("data/whole"):
#     if "csv" in file:
#         print(file)
#         df = pd.read_csv("/mnt/e/Bigdata/Top5LeaguesPlayerData/data/whole/"+file)
#         df = df.fillna(-1)
#         df.to_csv("/mnt/e/Bigdata/Top5LeaguesPlayerData/data/whole/fillna/"+file, index=False)
#         print(df)
#         print("")

# %%
serieAdf = []
for file in os.listdir("data/whole/fillna"):
    if "csv" in file:
        print(file)
        df = pd.read_csv("./data/whole/fillna/"+file)
        serieAdf.append(df)
        print("")
# Out:
# whole-2018,2019.csv-Bundesliga-with_value.csv
#
# whole-2018,2019.csv-La-Liga-with_value.csv
#
# whole-2018,2019.csv-Ligue-1-with_value.csv
#
# whole-2018,2019.csv-Premier-League-with_value.csv
#
# whole-2018,2019.csv-Serie-A-with_value.csv
#
# whole-2019,2020.csv-Bundesliga-with_value.csv
#
# whole-2019,2020.csv-La-Liga-with_value.csv
#
# whole-2019,2020.csv-Ligue-1-with_value.csv
#
# whole-2019,2020.csv-Premier-League-with_value.csv
#
# whole-2019,2020.csv-Serie-A-with_value.csv
#
# whole-2020,2021.csv-Bundesliga-with_value.csv
#
# whole-2020,2021.csv-La-Liga-with_value.csv
#
# whole-2020,2021.csv-Ligue-1-with_value.csv
#
# whole-2020,2021.csv-Premier-League-with_value.csv
#
# whole-2020,2021.csv-Serie-A-with_value.csv
#
# whole-2021,2022.csv-Bundesliga-with_value.csv
#
# whole-2021,2022.csv-La-Liga-with_value.csv
#
# whole-2021,2022.csv-Ligue-1-with_value.csv
#
# whole-2021,2022.csv-Premier-League-with_value.csv
#
# whole-2021,2022.csv-Serie-A-with_value.csv
#
# whole-2022,2023.csv-Bundesliga-with_value.csv
#
# whole-2022,2023.csv-La-Liga-with_value.csv
#
# whole-2022,2023.csv-Ligue-1-with_value.csv
#
# whole-2022,2023.csv-Premier-League-with_value.csv
#
# whole-2022,2023.csv-Serie-A-with_value.csv

# %%
serieAdf = pd.concat(serieAdf)

# %%
serieAdf.columns
# Out:
# Index(['Player', 'Nation', 'Pos', 'Age', 'MP', 'Playing Time_Starts',
#        'Playing Time.1_Min', 'Playing Time.2_90s', 'Performance_Gls',
#        'Performance.1_Ast', 'Performance.2_G+A', 'Performance.3_G-PK',
#        'Performance.4_PK', 'Performance.5_PKatt', 'Performance.6_CrdY',
#        'Performance.7_CrdR', 'Expected_xG', 'Expected.1_npxG',
#        'Expected.2_xAG', 'Expected.3_npxG+xAG', 'Progression_PrgC',
#        'Progression.1_PrgP', 'Progression.2_PrgR', 'Per 90 Minutes_Gls',
#        'Per 90 Minutes.1_Ast', 'Per 90 Minutes.2_G+A', 'Per 90 Minutes.3_G-PK',
#        'Per 90 Minutes.4_G+A-PK', 'Per 90 Minutes.5_xG',
#        'Per 90 Minutes.6_xAG', 'Per 90 Minutes.7_xG+xAG',
#        'Per 90 Minutes.8_npxG', 'Per 90 Minutes.9_npxG+xAG', 'Playing Time_MP',
#        'Playing Time.1_Starts', 'Playing Time.2_Min', 'Playing Time.3_90s',
#        'value', '0'],
#       dtype='object')

# %%
serieAdf = serieAdf.fillna(-1)
serieAdf = serieAdf.drop(columns=['Player', 'Nation'])

# %%
def secondPosition(x):
    if "," in x:
        return x.split(",")[1]
    else:
        return None

serieAdf['SecondaryPos'] = serieAdf['Pos'].apply(secondPosition)
serieAdf['Pos'] = serieAdf['Pos'].apply(lambda x: x.split(",")[0])
serieAdf.reset_index(drop=True, inplace=True)

# %%
corr = serieAdf.corr(numeric_only=True)
hc = findCorrelation(corr, cutoff=0.75)
serieAdfTrimmed = serieAdf.drop(columns=hc)

# %%
serieAdfTrimmed
# Out:
#       Pos   Age  Playing Time_Starts  Performance.3_G-PK  Performance.5_PKatt  \
# 0      MF  34.0                 36.0                 0.0                  0.0
# 1      DF  24.0                 34.0                 4.0                  0.0
# 2      DF  24.0                 34.0                 4.0                  0.0
# 3      MF  24.0                 32.0                 7.0                  1.0
# 4      DF  28.0                 29.0                 3.0                  0.0
# ...    ..   ...                  ...                 ...                  ...
# 17115  GK  18.0                  0.0                -1.0                 -1.0
# 17116  MF  18.0                  0.0                -1.0                 -1.0
# 17117  MF  17.0                  0.0                -1.0                 -1.0
# 17118  MF  18.0                  0.0                -1.0                 -1.0
# 17119  MF  19.0                  0.0                -1.0                 -1.0
#
#        Performance.6_CrdY  Performance.7_CrdR  Progression.1_PrgP  \
# 0                     7.0                 0.0               187.0
# 1                     7.0                 0.0                72.0
# 2                     2.0                 0.0                89.0
# 3                     5.0                 0.0               102.0
# 4                     1.0                 0.0               109.0
# ...                   ...                 ...                 ...
# 17115                -1.0                -1.0                -1.0
# 17116                -1.0                -1.0                -1.0
# 17117                -1.0                -1.0                -1.0
# 17118                -1.0                -1.0                -1.0
# 17119                -1.0                -1.0                -1.0
#
#        Progression.2_PrgR  Per 90 Minutes.4_G+A-PK  Per 90 Minutes.8_npxG  \
# 0                    34.0                     0.03                   0.03
# 1                    27.0                     0.15                   0.05
# 2                   155.0                     0.24                   0.08
# 3                   145.0                     0.28                   0.34
# 4                    87.0                     0.34                   0.03
# ...                   ...                      ...                    ...
# 17115                -1.0                    -1.00                  -1.00
# 17116                -1.0                    -1.00                  -1.00
# 17117                -1.0                    -1.00                  -1.00
# 17118                -1.0                    -1.00                  -1.00
# 17119                -1.0                    -1.00                  -1.00
#
#        Playing Time.1_Starts       value   0 SecondaryPos
# 0                       -1.0        -1.0  -1         None
# 1                       -1.0  10000000.0  -1           MF
# 2                       -1.0  17000000.0  -1           MF
# 3                       -1.0   7000000.0  -1           FW
# 4                       -1.0   5000000.0  -1         None
# ...                      ...         ...  ..          ...
# 17115                   -1.0     50000.0  -1         None
# 17116                   -1.0     10000.0  -1         None
# 17117                   -1.0        -1.0  -1         None
# 17118                   -1.0     75000.0  -1         None
# 17119                   -1.0     50000.0  -1         None
#
# [17120 rows x 15 columns]

# %%
# from xgboost import XGBRegressor
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import OrdinalEncoder, StandardScaler

X = serieAdfTrimmed.drop(columns=['value'])
X['Pos'] = X['Pos'].astype(str).fillna("Sconosciuta")
X['SecondaryPos'] = X['SecondaryPos'].astype(str).fillna("Sconosciuta")
y = serieAdfTrimmed['value']
scaler = StandardScaler()
pos = OrdinalEncoder().fit_transform(X['Pos'].values.reshape(-1, 1))
spos = OrdinalEncoder().fit_transform(X['SecondaryPos'].values.reshape(-1, 1))
X['Pos'] = pd.Series(pos.flatten())
X['SecondaryPos'] = pd.Series(spos.flatten())
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.values.reshape(-1, 1))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = ElasticNet()
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(mean_squared_error(y_test, y_pred))
print(r2_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_855/2060039468.py in ?()
# ---> 16 # from xgboost import XGBRegressor
#      17 from sklearn.linear_model import ElasticNet
#      18 from sklearn.model_selection import train_test_split
#      19 from sklearn.metrics import mean_squared_error, r2_score
#
# ~/miniconda3/envs/mldeep/lib/python3.9/site-packages/sklearn/utils/_set_output.py in ?(self, X, *args, **kwargs)
#     293     @wraps(f)
#     294     def wrapped(self, X, *args, **kwargs):
# --> 295         data_to_wrap = f(self, X, *args, **kwargs)
#     296         if isinstance(data_to_wrap, tuple):
#     297             # only wrap the first output for cross decomposition
#     298             return_tuple = (
#
# ~/miniconda3/envs/mldeep/lib/python3.9/site-packages/sklearn/base.py in ?(self, X, y, **fit_params)
#    1094                 )
#    1095
#    1096         if y is None:
#    1097             # fit method of arity 1 (unsupervised transformation)
# -> 1098             return self.fit(X, **fit_params).transform(X)
#    1099         else:
#    1100             # fit method of arity 2 (supervised transformation)
#    1101             return self.fit(X, y, **fit_params).transform(X)
#
# ~/miniconda3/envs/mldeep/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y, sample_weight)
#     872             Fitted scaler.
#     873         """
#     874         # Reset internal state before fitting
#     875         self._reset()
# --> 876         return self.partial_fit(X, y, sample_weight)
#
# ~/miniconda3/envs/mldeep/lib/python3.9/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1470                 skip_parameter_validation=(
#    1471                     prefer_skip_nested_validation or global_skip_validation
#    1472                 )
#    1473             ):
# -> 1474                 return fit_method(estimator, *args, **kwargs)
#
# ~/miniconda3/envs/mldeep/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y, sample_weight)
#     908         self : object
#     909             Fitted scaler.
#     910         """
#     911         first_call = not hasattr(self, "n_samples_seen_")
# --> 912         X = self._validate_data(
#     913             X,
#     914             accept_sparse=("csr", "csc"),
#     915             dtype=FLOAT_DTYPES,
#
# ~/miniconda3/envs/mldeep/lib/python3.9/site-packages/sklearn/base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     629                 out = y
#     630             else:
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#     636         else:
#
# ~/miniconda3/envs/mldeep/lib/python3.9/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     995                     array = xp.astype(array, dtype, copy=False)
#     996                 else:
#     997                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     998             except ComplexWarning as complex_warning:
# --> 999                 raise ValueError(
#    1000                     "Complex data not supported\n{}\n".format(array)
#    1001                 ) from complex_warning
#    1002
#
# ~/miniconda3/envs/mldeep/lib/python3.9/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp)
#     517         # Use NumPy API to support order
#     518         if copy is True:
#     519             array = numpy.array(array, order=order, dtype=dtype)
#     520         else:
# --> 521             array = numpy.asarray(array, order=order, dtype=dtype)
#     522
#     523         # At this point array is a NumPy ndarray. We convert it to an array
#     524         # container that is consistent with the input's namespace.
#
# ~/miniconda3/envs/mldeep/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, dtype)
#    1996     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    1997         values = self._values
# -> 1998         arr = np.asarray(values, dtype=dtype)
#    1999         if (
#    2000             astype_is_view(values.dtype, arr.dtype)
#    2001             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Player                       Dominique Heintz\nNation                                 de GER\nPos                                        DF\nAge                                        28\nMP                                       12.0\nPlaying Time_Starts                       8.0\nPlaying Time.1_Min                      822.0\nPlaying Time.2_90s                        9.1\nPerformance_Gls                           0.0\nPerformance.1_Ast                         0.0\nPerformance.2_G+A                         0.0\nPerformance.3_G-PK                        0.0\nPerformance.4_PK                          0.0\nPerformance.5_PKatt                       0.0\nPerformance.6_CrdY                        1.0\nPerformance.7_CrdR                        0.0\nExpected_xG                               0.3\nExpected.1_npxG                           0.3\nExpected.2_xAG                            0.2\nExpected.3_npxG+xAG                       0.5\nProgression_PrgC                          3.0\nProgression.1_PrgP                       21.0\nProgression.2_PrgR                        2.0\nPer 90 Minutes_Gls                        0.0\nPer 90 Minutes.1_Ast                      0.0\nPer 90 Minutes.2_G+A                      0.0\nPer 90 Minutes.3_G-PK                     0.0\nPer 90 Minutes.4_G+A-PK                   0.0\nPer 90 Minutes.5_xG                      0.04\nPer 90 Minutes.6_xAG                     0.02\nPer 90 Minutes.7_xG+xAG                  0.06\nPer 90 Minutes.8_npxG                    0.04\nPer 90 Minutes.9_npxG+xAG                0.06\nPlaying Time_MP                           NaN\nPlaying Time.1_Starts                     NaN\nPlaying Time.2_Min                        NaN\nPlaying Time.3_90s                        NaN\nvalue                               1500000.0\nName: 125, dtype: object'

# %%
from keras import Sequential
from keras import layers
from keras import ops
model = Sequential(
    [
        layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
        layers.Dense(64, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(1)
    ]
)
# Out:
# /home/matteo/miniconda3/envs/mldeep/lib/python3.9/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 128)            │         1,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,305 (71.50 KB)
#  Trainable params: 18,305 (71.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import mlflow.keras
run = mlflow.start_run(run_name="Keras")
model.compile(
    optimizer='adam',
    loss='mean_squared_error',
    metrics=['mean_squared_error', "r2_score", "mean_absolute_error", "mean_absolute_percentage_error"]
)
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, callbacks=[mlflow.keras.MlflowCallback(run)])
test_scores = model.evaluate(X_test, y_test, verbose=2,  callbacks=[mlflow.keras.MlflowCallback(run)])
mlflow.end_run()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 2024/05/12 18:36:06 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during autologging: The configured tracking uri scheme: 'file' is invalid for use with the proxy mlflow-artifact scheme. The allowed tracking schemes are: {'https', 'http'}
# Epoch 1/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0706 - mean_absolute_error: 0.1593 - mean_absolute_percentage_error: 290.4974 - mean_squared_error: 0.0706 - r2_score: 0.9322 - val_loss: 0.5326 - val_mean_absolute_error: 0.3709 - val_mean_absolute_percentage_error: 551.3778 - val_mean_squared_error: 0.5326 - val_r2_score: 0.3032
# Epoch 2/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0541 - mean_absolute_error: 0.1365 - mean_absolute_percentage_error: 208.7081 - mean_squared_error: 0.0541 - r2_score: 0.9436 - val_loss: 0.5159 - val_mean_absolute_error: 0.3626 - val_mean_absolute_percentage_error: 492.6307 - val_mean_squared_error: 0.5159 - val_r2_score: 0.3251
# Epoch 3/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0475 - mean_absolute_error: 0.1279 - mean_absolute_percentage_error: 264.7182 - mean_squared_error: 0.0475 - r2_score: 0.9531 - val_loss: 0.5311 - val_mean_absolute_error: 0.3637 - val_mean_absolute_percentage_error: 508.7603 - val_mean_squared_error: 0.5311 - val_r2_score: 0.3053
# Epoch 4/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0444 - mean_absolute_error: 0.1230 - mean_absolute_percentage_error: 259.5669 - mean_squared_error: 0.0444 - r2_score: 0.9541 - val_loss: 0.5633 - val_mean_absolute_error: 0.3699 - val_mean_absolute_percentage_error: 548.5155 - val_mean_squared_error: 0.5633 - val_r2_score: 0.2631
# Epoch 5/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0503 - mean_absolute_error: 0.1320 - mean_absolute_percentage_error: 256.1971 - mean_squared_error: 0.0503 - r2_score: 0.9451 - val_loss: 0.5171 - val_mean_absolute_error: 0.3660 - val_mean_absolute_percentage_error: 537.3539 - val_mean_squared_error: 0.5171 - val_r2_score: 0.3235
# Epoch 6/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0533 - mean_absolute_error: 0.1340 - mean_absolute_percentage_error: 260.4164 - mean_squared_error: 0.0533 - r2_score: 0.9549 - val_loss: 0.5060 - val_mean_absolute_error: 0.3622 - val_mean_absolute_percentage_error: 502.5167 - val_mean_squared_error: 0.5060 - val_r2_score: 0.3381
# Epoch 7/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0577 - mean_absolute_error: 0.1308 - mean_absolute_percentage_error: 314.1473 - mean_squared_error: 0.0577 - r2_score: 0.9413 - val_loss: 0.5598 - val_mean_absolute_error: 0.3739 - val_mean_absolute_percentage_error: 511.8112 - val_mean_squared_error: 0.5598 - val_r2_score: 0.2677
# Epoch 8/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0454 - mean_absolute_error: 0.1262 - mean_absolute_percentage_error: 296.5190 - mean_squared_error: 0.0454 - r2_score: 0.9554 - val_loss: 0.5372 - val_mean_absolute_error: 0.3677 - val_mean_absolute_percentage_error: 547.1169 - val_mean_squared_error: 0.5372 - val_r2_score: 0.2972
# Epoch 9/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0668 - mean_absolute_error: 0.1424 - mean_absolute_percentage_error: 336.0969 - mean_squared_error: 0.0668 - r2_score: 0.9273 - val_loss: 0.5204 - val_mean_absolute_error: 0.3673 - val_mean_absolute_percentage_error: 466.3694 - val_mean_squared_error: 0.5204 - val_r2_score: 0.3192
# Epoch 10/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0773 - mean_absolute_error: 0.1625 - mean_absolute_percentage_error: 370.8735 - mean_squared_error: 0.0773 - r2_score: 0.9270 - val_loss: 0.5172 - val_mean_absolute_error: 0.3593 - val_mean_absolute_percentage_error: 552.9661 - val_mean_squared_error: 0.5172 - val_r2_score: 0.3234
# Epoch 11/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0640 - mean_absolute_error: 0.1535 - mean_absolute_percentage_error: 293.6741 - mean_squared_error: 0.0640 - r2_score: 0.9406 - val_loss: 0.5332 - val_mean_absolute_error: 0.3608 - val_mean_absolute_percentage_error: 509.2471 - val_mean_squared_error: 0.5332 - val_r2_score: 0.3024
# Epoch 12/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0521 - mean_absolute_error: 0.1298 - mean_absolute_percentage_error: 264.7129 - mean_squared_error: 0.0521 - r2_score: 0.9485 - val_loss: 0.5157 - val_mean_absolute_error: 0.3566 - val_mean_absolute_percentage_error: 553.5024 - val_mean_squared_error: 0.5157 - val_r2_score: 0.3253
# Epoch 13/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0539 - mean_absolute_error: 0.1334 - mean_absolute_percentage_error: 280.4798 - mean_squared_error: 0.0539 - r2_score: 0.9483 - val_loss: 0.5299 - val_mean_absolute_error: 0.3586 - val_mean_absolute_percentage_error: 521.6932 - val_mean_squared_error: 0.5299 - val_r2_score: 0.3068
# Epoch 14/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0415 - mean_absolute_error: 0.1278 - mean_absolute_percentage_error: 242.7416 - mean_squared_error: 0.0415 - r2_score: 0.9608 - val_loss: 0.5249 - val_mean_absolute_error: 0.3600 - val_mean_absolute_percentage_error: 545.7018 - val_mean_squared_error: 0.5249 - val_r2_score: 0.3133
# Epoch 15/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0334 - mean_absolute_error: 0.1052 - mean_absolute_percentage_error: 228.4985 - mean_squared_error: 0.0334 - r2_score: 0.9693 - val_loss: 0.5069 - val_mean_absolute_error: 0.3617 - val_mean_absolute_percentage_error: 519.1831 - val_mean_squared_error: 0.5069 - val_r2_score: 0.3368
# Epoch 16/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0358 - mean_absolute_error: 0.1108 - mean_absolute_percentage_error: 224.1818 - mean_squared_error: 0.0358 - r2_score: 0.9659 - val_loss: 0.5220 - val_mean_absolute_error: 0.3744 - val_mean_absolute_percentage_error: 534.5680 - val_mean_squared_error: 0.5220 - val_r2_score: 0.3171
# Epoch 17/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0430 - mean_absolute_error: 0.1135 - mean_absolute_percentage_error: 241.2029 - mean_squared_error: 0.0430 - r2_score: 0.9557 - val_loss: 0.5333 - val_mean_absolute_error: 0.3710 - val_mean_absolute_percentage_error: 510.2115 - val_mean_squared_error: 0.5333 - val_r2_score: 0.3023
# Epoch 18/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0364 - mean_absolute_error: 0.1131 - mean_absolute_percentage_error: 227.3890 - mean_squared_error: 0.0364 - r2_score: 0.9649 - val_loss: 0.5467 - val_mean_absolute_error: 0.3638 - val_mean_absolute_percentage_error: 558.4632 - val_mean_squared_error: 0.5467 - val_r2_score: 0.2848
# Epoch 19/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0631 - mean_absolute_error: 0.1217 - mean_absolute_percentage_error: 224.7969 - mean_squared_error: 0.0631 - r2_score: 0.9293 - val_loss: 0.5145 - val_mean_absolute_error: 0.3570 - val_mean_absolute_percentage_error: 548.2864 - val_mean_squared_error: 0.5145 - val_r2_score: 0.3269
# Epoch 20/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0331 - mean_absolute_error: 0.1059 - mean_absolute_percentage_error: 250.9797 - mean_squared_error: 0.0331 - r2_score: 0.9698 - val_loss: 0.5254 - val_mean_absolute_error: 0.3706 - val_mean_absolute_percentage_error: 518.5142 - val_mean_squared_error: 0.5254 - val_r2_score: 0.3127
# Epoch 21/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0460 - mean_absolute_error: 0.1247 - mean_absolute_percentage_error: 319.7506 - mean_squared_error: 0.0460 - r2_score: 0.9579 - val_loss: 0.5157 - val_mean_absolute_error: 0.3624 - val_mean_absolute_percentage_error: 556.8856 - val_mean_squared_error: 0.5157 - val_r2_score: 0.3253
# Epoch 22/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0412 - mean_absolute_error: 0.1142 - mean_absolute_percentage_error: 242.2628 - mean_squared_error: 0.0412 - r2_score: 0.9592 - val_loss: 0.5267 - val_mean_absolute_error: 0.3638 - val_mean_absolute_percentage_error: 564.8045 - val_mean_squared_error: 0.5267 - val_r2_score: 0.3109
# Epoch 23/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0381 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 257.6643 - mean_squared_error: 0.0381 - r2_score: 0.9614 - val_loss: 0.5699 - val_mean_absolute_error: 0.3735 - val_mean_absolute_percentage_error: 553.7274 - val_mean_squared_error: 0.5699 - val_r2_score: 0.2544
# Epoch 24/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0559 - mean_absolute_error: 0.1335 - mean_absolute_percentage_error: 306.2679 - mean_squared_error: 0.0559 - r2_score: 0.9442 - val_loss: 0.5444 - val_mean_absolute_error: 0.3660 - val_mean_absolute_percentage_error: 555.7538 - val_mean_squared_error: 0.5444 - val_r2_score: 0.2879
# Epoch 25/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0542 - mean_absolute_error: 0.1276 - mean_absolute_percentage_error: 250.5337 - mean_squared_error: 0.0542 - r2_score: 0.9499 - val_loss: 0.5093 - val_mean_absolute_error: 0.3565 - val_mean_absolute_percentage_error: 486.2641 - val_mean_squared_error: 0.5093 - val_r2_score: 0.3337
# Epoch 26/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0469 - mean_absolute_error: 0.1185 - mean_absolute_percentage_error: 300.6320 - mean_squared_error: 0.0469 - r2_score: 0.9535 - val_loss: 0.5074 - val_mean_absolute_error: 0.3517 - val_mean_absolute_percentage_error: 514.5516 - val_mean_squared_error: 0.5074 - val_r2_score: 0.3362
# Epoch 27/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0431 - mean_absolute_error: 0.1098 - mean_absolute_percentage_error: 172.5139 - mean_squared_error: 0.0431 - r2_score: 0.9597 - val_loss: 0.5437 - val_mean_absolute_error: 0.3667 - val_mean_absolute_percentage_error: 510.9787 - val_mean_squared_error: 0.5437 - val_r2_score: 0.2887
# Epoch 28/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0406 - mean_absolute_error: 0.1080 - mean_absolute_percentage_error: 312.9895 - mean_squared_error: 0.0406 - r2_score: 0.9559 - val_loss: 0.5628 - val_mean_absolute_error: 0.3787 - val_mean_absolute_percentage_error: 535.8746 - val_mean_squared_error: 0.5628 - val_r2_score: 0.2637
# Epoch 29/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0486 - mean_absolute_error: 0.1126 - mean_absolute_percentage_error: 385.9538 - mean_squared_error: 0.0486 - r2_score: 0.9396 - val_loss: 0.5195 - val_mean_absolute_error: 0.3745 - val_mean_absolute_percentage_error: 503.7049 - val_mean_squared_error: 0.5195 - val_r2_score: 0.3204
# Epoch 30/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0433 - mean_absolute_error: 0.1158 - mean_absolute_percentage_error: 181.7562 - mean_squared_error: 0.0433 - r2_score: 0.9617 - val_loss: 0.5120 - val_mean_absolute_error: 0.3733 - val_mean_absolute_percentage_error: 468.3539 - val_mean_squared_error: 0.5120 - val_r2_score: 0.3302
# Epoch 31/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0446 - mean_absolute_error: 0.1264 - mean_absolute_percentage_error: 211.3714 - mean_squared_error: 0.0446 - r2_score: 0.9616 - val_loss: 0.5146 - val_mean_absolute_error: 0.3668 - val_mean_absolute_percentage_error: 522.4940 - val_mean_squared_error: 0.5146 - val_r2_score: 0.3268
# Epoch 32/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0364 - mean_absolute_error: 0.1100 - mean_absolute_percentage_error: 298.9531 - mean_squared_error: 0.0364 - r2_score: 0.9602 - val_loss: 0.5178 - val_mean_absolute_error: 0.3621 - val_mean_absolute_percentage_error: 537.8571 - val_mean_squared_error: 0.5178 - val_r2_score: 0.3226
# Epoch 33/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0348 - mean_absolute_error: 0.1067 - mean_absolute_percentage_error: 197.5164 - mean_squared_error: 0.0348 - r2_score: 0.9662 - val_loss: 0.5011 - val_mean_absolute_error: 0.3499 - val_mean_absolute_percentage_error: 557.4225 - val_mean_squared_error: 0.5011 - val_r2_score: 0.3445
# Epoch 34/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0411 - mean_absolute_error: 0.1052 - mean_absolute_percentage_error: 197.5114 - mean_squared_error: 0.0411 - r2_score: 0.9623 - val_loss: 0.5251 - val_mean_absolute_error: 0.3738 - val_mean_absolute_percentage_error: 525.8138 - val_mean_squared_error: 0.5251 - val_r2_score: 0.3130
# Epoch 35/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0379 - mean_absolute_error: 0.1066 - mean_absolute_percentage_error: 165.2294 - mean_squared_error: 0.0379 - r2_score: 0.9653 - val_loss: 0.5279 - val_mean_absolute_error: 0.3567 - val_mean_absolute_percentage_error: 556.8923 - val_mean_squared_error: 0.5279 - val_r2_score: 0.3094
# Epoch 36/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0418 - mean_absolute_error: 0.1104 - mean_absolute_percentage_error: 238.5743 - mean_squared_error: 0.0418 - r2_score: 0.9587 - val_loss: 0.5150 - val_mean_absolute_error: 0.3663 - val_mean_absolute_percentage_error: 520.1935 - val_mean_squared_error: 0.5150 - val_r2_score: 0.3263
# Epoch 37/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0456 - mean_absolute_error: 0.1102 - mean_absolute_percentage_error: 200.0440 - mean_squared_error: 0.0456 - r2_score: 0.9534 - val_loss: 0.5282 - val_mean_absolute_error: 0.3713 - val_mean_absolute_percentage_error: 519.1281 - val_mean_squared_error: 0.5282 - val_r2_score: 0.3090
# Epoch 38/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0747 - mean_absolute_error: 0.1483 - mean_absolute_percentage_error: 336.2773 - mean_squared_error: 0.0747 - r2_score: 0.9214 - val_loss: 0.5111 - val_mean_absolute_error: 0.3557 - val_mean_absolute_percentage_error: 551.5981 - val_mean_squared_error: 0.5111 - val_r2_score: 0.3314
# Epoch 39/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0884 - mean_absolute_error: 0.1704 - mean_absolute_percentage_error: 309.9697 - mean_squared_error: 0.0884 - r2_score: 0.9239 - val_loss: 0.5947 - val_mean_absolute_error: 0.4088 - val_mean_absolute_percentage_error: 575.4483 - val_mean_squared_error: 0.5947 - val_r2_score: 0.2221
# Epoch 40/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1631 - mean_absolute_error: 0.2274 - mean_absolute_percentage_error: 401.8246 - mean_squared_error: 0.1631 - r2_score: 0.8303 - val_loss: 0.5470 - val_mean_absolute_error: 0.3780 - val_mean_absolute_percentage_error: 595.2080 - val_mean_squared_error: 0.5470 - val_r2_score: 0.2844
# Epoch 41/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1203 - mean_absolute_error: 0.2037 - mean_absolute_percentage_error: 332.5189 - mean_squared_error: 0.1203 - r2_score: 0.8695 - val_loss: 0.5333 - val_mean_absolute_error: 0.3821 - val_mean_absolute_percentage_error: 477.9416 - val_mean_squared_error: 0.5333 - val_r2_score: 0.3023
# Epoch 42/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0900 - mean_absolute_error: 0.1716 - mean_absolute_percentage_error: 314.5677 - mean_squared_error: 0.0900 - r2_score: 0.9176 - val_loss: 0.5425 - val_mean_absolute_error: 0.3639 - val_mean_absolute_percentage_error: 576.3088 - val_mean_squared_error: 0.5425 - val_r2_score: 0.2903
# Epoch 43/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0610 - mean_absolute_error: 0.1409 - mean_absolute_percentage_error: 317.2069 - mean_squared_error: 0.0610 - r2_score: 0.9389 - val_loss: 0.5179 - val_mean_absolute_error: 0.3541 - val_mean_absolute_percentage_error: 520.2941 - val_mean_squared_error: 0.5179 - val_r2_score: 0.3225
# Epoch 44/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0457 - mean_absolute_error: 0.1235 - mean_absolute_percentage_error: 299.8977 - mean_squared_error: 0.0457 - r2_score: 0.9538 - val_loss: 0.5472 - val_mean_absolute_error: 0.3679 - val_mean_absolute_percentage_error: 571.6978 - val_mean_squared_error: 0.5472 - val_r2_score: 0.2841
# Epoch 45/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0341 - mean_absolute_error: 0.1092 - mean_absolute_percentage_error: 242.7821 - mean_squared_error: 0.0341 - r2_score: 0.9640 - val_loss: 0.5195 - val_mean_absolute_error: 0.3588 - val_mean_absolute_percentage_error: 562.4655 - val_mean_squared_error: 0.5195 - val_r2_score: 0.3204
# Epoch 46/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0428 - mean_absolute_error: 0.1158 - mean_absolute_percentage_error: 261.5539 - mean_squared_error: 0.0428 - r2_score: 0.9529 - val_loss: 0.5375 - val_mean_absolute_error: 0.3682 - val_mean_absolute_percentage_error: 557.1685 - val_mean_squared_error: 0.5375 - val_r2_score: 0.2968
# Epoch 47/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0319 - mean_absolute_error: 0.0952 - mean_absolute_percentage_error: 260.9937 - mean_squared_error: 0.0319 - r2_score: 0.9671 - val_loss: 0.5253 - val_mean_absolute_error: 0.3556 - val_mean_absolute_percentage_error: 546.8500 - val_mean_squared_error: 0.5253 - val_r2_score: 0.3128
# Epoch 48/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0372 - mean_absolute_error: 0.1017 - mean_absolute_percentage_error: 256.4821 - mean_squared_error: 0.0372 - r2_score: 0.9623 - val_loss: 0.5341 - val_mean_absolute_error: 0.3667 - val_mean_absolute_percentage_error: 527.6198 - val_mean_squared_error: 0.5341 - val_r2_score: 0.3013
# Epoch 49/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0284 - mean_absolute_error: 0.0936 - mean_absolute_percentage_error: 213.0370 - mean_squared_error: 0.0284 - r2_score: 0.9668 - val_loss: 0.5248 - val_mean_absolute_error: 0.3639 - val_mean_absolute_percentage_error: 557.7910 - val_mean_squared_error: 0.5248 - val_r2_score: 0.3134
# Epoch 50/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0326 - mean_absolute_error: 0.0965 - mean_absolute_percentage_error: 176.3405 - mean_squared_error: 0.0326 - r2_score: 0.9680 - val_loss: 0.5308 - val_mean_absolute_error: 0.3660 - val_mean_absolute_percentage_error: 544.0370 - val_mean_squared_error: 0.5308 - val_r2_score: 0.3056
# Epoch 51/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0395 - mean_absolute_error: 0.0980 - mean_absolute_percentage_error: 170.0240 - mean_squared_error: 0.0395 - r2_score: 0.9517 - val_loss: 0.5486 - val_mean_absolute_error: 0.3620 - val_mean_absolute_percentage_error: 553.5237 - val_mean_squared_error: 0.5486 - val_r2_score: 0.2823
# Epoch 52/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0350 - mean_absolute_error: 0.0894 - mean_absolute_percentage_error: 228.2951 - mean_squared_error: 0.0350 - r2_score: 0.9634 - val_loss: 0.5217 - val_mean_absolute_error: 0.3625 - val_mean_absolute_percentage_error: 542.0851 - val_mean_squared_error: 0.5217 - val_r2_score: 0.3175
# Epoch 53/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0237 - mean_absolute_error: 0.0874 - mean_absolute_percentage_error: 193.4248 - mean_squared_error: 0.0237 - r2_score: 0.9752 - val_loss: 0.5377 - val_mean_absolute_error: 0.3741 - val_mean_absolute_percentage_error: 518.7624 - val_mean_squared_error: 0.5377 - val_r2_score: 0.2966
# Epoch 54/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0312 - mean_absolute_error: 0.0917 - mean_absolute_percentage_error: 276.3590 - mean_squared_error: 0.0312 - r2_score: 0.9644 - val_loss: 0.5283 - val_mean_absolute_error: 0.3590 - val_mean_absolute_percentage_error: 580.4103 - val_mean_squared_error: 0.5283 - val_r2_score: 0.3088
# Epoch 55/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0313 - mean_absolute_error: 0.0910 - mean_absolute_percentage_error: 190.4896 - mean_squared_error: 0.0313 - r2_score: 0.9639 - val_loss: 0.5207 - val_mean_absolute_error: 0.3707 - val_mean_absolute_percentage_error: 531.0309 - val_mean_squared_error: 0.5207 - val_r2_score: 0.3189
# Epoch 56/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0326 - mean_absolute_error: 0.0945 - mean_absolute_percentage_error: 212.6050 - mean_squared_error: 0.0326 - r2_score: 0.9690 - val_loss: 0.5424 - val_mean_absolute_error: 0.3635 - val_mean_absolute_percentage_error: 512.8777 - val_mean_squared_error: 0.5424 - val_r2_score: 0.2905
# Epoch 57/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0308 - mean_absolute_error: 0.0959 - mean_absolute_percentage_error: 198.6792 - mean_squared_error: 0.0308 - r2_score: 0.9691 - val_loss: 0.5275 - val_mean_absolute_error: 0.3599 - val_mean_absolute_percentage_error: 544.5322 - val_mean_squared_error: 0.5275 - val_r2_score: 0.3100
# Epoch 58/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0434 - mean_absolute_error: 0.1040 - mean_absolute_percentage_error: 205.1990 - mean_squared_error: 0.0434 - r2_score: 0.9571 - val_loss: 0.5308 - val_mean_absolute_error: 0.3602 - val_mean_absolute_percentage_error: 540.8801 - val_mean_squared_error: 0.5308 - val_r2_score: 0.3056
# Epoch 59/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0355 - mean_absolute_error: 0.1015 - mean_absolute_percentage_error: 210.1380 - mean_squared_error: 0.0355 - r2_score: 0.9660 - val_loss: 0.5365 - val_mean_absolute_error: 0.3700 - val_mean_absolute_percentage_error: 544.3245 - val_mean_squared_error: 0.5365 - val_r2_score: 0.2981
# Epoch 60/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0410 - mean_absolute_error: 0.1091 - mean_absolute_percentage_error: 181.6747 - mean_squared_error: 0.0410 - r2_score: 0.9622 - val_loss: 0.5203 - val_mean_absolute_error: 0.3593 - val_mean_absolute_percentage_error: 509.5936 - val_mean_squared_error: 0.5203 - val_r2_score: 0.3193
# Epoch 61/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0502 - mean_absolute_error: 0.1205 - mean_absolute_percentage_error: 227.6380 - mean_squared_error: 0.0502 - r2_score: 0.9453 - val_loss: 0.5378 - val_mean_absolute_error: 0.3659 - val_mean_absolute_percentage_error: 501.4721 - val_mean_squared_error: 0.5378 - val_r2_score: 0.2964
# Epoch 62/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0616 - mean_absolute_error: 0.1361 - mean_absolute_percentage_error: 271.0168 - mean_squared_error: 0.0616 - r2_score: 0.9370 - val_loss: 0.5293 - val_mean_absolute_error: 0.3858 - val_mean_absolute_percentage_error: 514.7657 - val_mean_squared_error: 0.5293 - val_r2_score: 0.3075
# Epoch 63/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0580 - mean_absolute_error: 0.1454 - mean_absolute_percentage_error: 338.7493 - mean_squared_error: 0.0580 - r2_score: 0.9455 - val_loss: 0.5244 - val_mean_absolute_error: 0.3638 - val_mean_absolute_percentage_error: 541.6804 - val_mean_squared_error: 0.5244 - val_r2_score: 0.3140
# Epoch 64/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0601 - mean_absolute_error: 0.1312 - mean_absolute_percentage_error: 325.2105 - mean_squared_error: 0.0601 - r2_score: 0.9302 - val_loss: 0.5488 - val_mean_absolute_error: 0.3734 - val_mean_absolute_percentage_error: 517.1744 - val_mean_squared_error: 0.5488 - val_r2_score: 0.2821
# Epoch 65/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0347 - mean_absolute_error: 0.1050 - mean_absolute_percentage_error: 223.7110 - mean_squared_error: 0.0347 - r2_score: 0.9653 - val_loss: 0.5314 - val_mean_absolute_error: 0.3584 - val_mean_absolute_percentage_error: 533.7197 - val_mean_squared_error: 0.5314 - val_r2_score: 0.3049
# Epoch 66/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0303 - mean_absolute_error: 0.0946 - mean_absolute_percentage_error: 168.9625 - mean_squared_error: 0.0303 - r2_score: 0.9677 - val_loss: 0.5437 - val_mean_absolute_error: 0.3656 - val_mean_absolute_percentage_error: 506.7227 - val_mean_squared_error: 0.5437 - val_r2_score: 0.2888
# Epoch 67/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0323 - mean_absolute_error: 0.0923 - mean_absolute_percentage_error: 188.1589 - mean_squared_error: 0.0323 - r2_score: 0.9676 - val_loss: 0.5194 - val_mean_absolute_error: 0.3579 - val_mean_absolute_percentage_error: 553.9089 - val_mean_squared_error: 0.5194 - val_r2_score: 0.3206
# Epoch 68/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0292 - mean_absolute_error: 0.0958 - mean_absolute_percentage_error: 232.5430 - mean_squared_error: 0.0292 - r2_score: 0.9727 - val_loss: 0.5414 - val_mean_absolute_error: 0.3688 - val_mean_absolute_percentage_error: 514.1866 - val_mean_squared_error: 0.5414 - val_r2_score: 0.2917
# Epoch 69/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0380 - mean_absolute_error: 0.0931 - mean_absolute_percentage_error: 249.7045 - mean_squared_error: 0.0380 - r2_score: 0.9625 - val_loss: 0.5317 - val_mean_absolute_error: 0.3611 - val_mean_absolute_percentage_error: 563.8162 - val_mean_squared_error: 0.5317 - val_r2_score: 0.3044
# Epoch 70/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0253 - mean_absolute_error: 0.0895 - mean_absolute_percentage_error: 210.0455 - mean_squared_error: 0.0253 - r2_score: 0.9740 - val_loss: 0.5217 - val_mean_absolute_error: 0.3658 - val_mean_absolute_percentage_error: 493.9044 - val_mean_squared_error: 0.5217 - val_r2_score: 0.3174
# Epoch 71/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0394 - mean_absolute_error: 0.1194 - mean_absolute_percentage_error: 263.0938 - mean_squared_error: 0.0394 - r2_score: 0.9559 - val_loss: 0.5239 - val_mean_absolute_error: 0.3620 - val_mean_absolute_percentage_error: 490.6526 - val_mean_squared_error: 0.5239 - val_r2_score: 0.3146
# Epoch 72/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0353 - mean_absolute_error: 0.0971 - mean_absolute_percentage_error: 226.2871 - mean_squared_error: 0.0353 - r2_score: 0.9649 - val_loss: 0.5357 - val_mean_absolute_error: 0.3632 - val_mean_absolute_percentage_error: 517.0350 - val_mean_squared_error: 0.5357 - val_r2_score: 0.2992
# Epoch 73/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0304 - mean_absolute_error: 0.0946 - mean_absolute_percentage_error: 153.2263 - mean_squared_error: 0.0304 - r2_score: 0.9739 - val_loss: 0.5152 - val_mean_absolute_error: 0.3618 - val_mean_absolute_percentage_error: 519.1460 - val_mean_squared_error: 0.5152 - val_r2_score: 0.3260
# Epoch 74/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0272 - mean_absolute_error: 0.0922 - mean_absolute_percentage_error: 216.2129 - mean_squared_error: 0.0272 - r2_score: 0.9713 - val_loss: 0.5413 - val_mean_absolute_error: 0.3663 - val_mean_absolute_percentage_error: 503.1945 - val_mean_squared_error: 0.5413 - val_r2_score: 0.2919
# Epoch 75/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0247 - mean_absolute_error: 0.0889 - mean_absolute_percentage_error: 156.0817 - mean_squared_error: 0.0247 - r2_score: 0.9770 - val_loss: 0.5323 - val_mean_absolute_error: 0.3710 - val_mean_absolute_percentage_error: 535.4500 - val_mean_squared_error: 0.5323 - val_r2_score: 0.3036
# Epoch 76/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0462 - mean_absolute_error: 0.0938 - mean_absolute_percentage_error: 184.9867 - mean_squared_error: 0.0462 - r2_score: 0.9533 - val_loss: 0.5247 - val_mean_absolute_error: 0.3640 - val_mean_absolute_percentage_error: 550.1016 - val_mean_squared_error: 0.5247 - val_r2_score: 0.3136
# Epoch 77/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0418 - mean_absolute_error: 0.1049 - mean_absolute_percentage_error: 201.9852 - mean_squared_error: 0.0418 - r2_score: 0.9560 - val_loss: 0.5084 - val_mean_absolute_error: 0.3589 - val_mean_absolute_percentage_error: 516.3173 - val_mean_squared_error: 0.5084 - val_r2_score: 0.3349
# Epoch 78/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0751 - mean_absolute_error: 0.1390 - mean_absolute_percentage_error: 249.3210 - mean_squared_error: 0.0751 - r2_score: 0.9191 - val_loss: 0.5343 - val_mean_absolute_error: 0.3648 - val_mean_absolute_percentage_error: 502.7568 - val_mean_squared_error: 0.5343 - val_r2_score: 0.3011
# Epoch 79/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0551 - mean_absolute_error: 0.1267 - mean_absolute_percentage_error: 225.6893 - mean_squared_error: 0.0551 - r2_score: 0.9430 - val_loss: 0.5229 - val_mean_absolute_error: 0.3706 - val_mean_absolute_percentage_error: 463.2020 - val_mean_squared_error: 0.5229 - val_r2_score: 0.3159
# Epoch 80/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0409 - mean_absolute_error: 0.1151 - mean_absolute_percentage_error: 273.4400 - mean_squared_error: 0.0409 - r2_score: 0.9529 - val_loss: 0.5573 - val_mean_absolute_error: 0.3789 - val_mean_absolute_percentage_error: 465.0363 - val_mean_squared_error: 0.5573 - val_r2_score: 0.2709
# Epoch 81/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0385 - mean_absolute_error: 0.1089 - mean_absolute_percentage_error: 194.3763 - mean_squared_error: 0.0385 - r2_score: 0.9603 - val_loss: 0.5420 - val_mean_absolute_error: 0.3689 - val_mean_absolute_percentage_error: 537.8597 - val_mean_squared_error: 0.5420 - val_r2_score: 0.2910
# Epoch 82/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0346 - mean_absolute_error: 0.0967 - mean_absolute_percentage_error: 200.9825 - mean_squared_error: 0.0346 - r2_score: 0.9624 - val_loss: 0.5589 - val_mean_absolute_error: 0.3667 - val_mean_absolute_percentage_error: 507.1473 - val_mean_squared_error: 0.5589 - val_r2_score: 0.2688
# Epoch 83/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0420 - mean_absolute_error: 0.1155 - mean_absolute_percentage_error: 187.3381 - mean_squared_error: 0.0420 - r2_score: 0.9545 - val_loss: 0.5253 - val_mean_absolute_error: 0.3657 - val_mean_absolute_percentage_error: 519.2877 - val_mean_squared_error: 0.5253 - val_r2_score: 0.3128
# Epoch 84/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0327 - mean_absolute_error: 0.1013 - mean_absolute_percentage_error: 277.3773 - mean_squared_error: 0.0327 - r2_score: 0.9483 - val_loss: 0.5464 - val_mean_absolute_error: 0.3729 - val_mean_absolute_percentage_error: 551.9263 - val_mean_squared_error: 0.5464 - val_r2_score: 0.2852
# Epoch 85/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0499 - mean_absolute_error: 0.1035 - mean_absolute_percentage_error: 206.4187 - mean_squared_error: 0.0499 - r2_score: 0.9354 - val_loss: 0.5387 - val_mean_absolute_error: 0.3721 - val_mean_absolute_percentage_error: 482.3152 - val_mean_squared_error: 0.5387 - val_r2_score: 0.2952
# Epoch 86/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0338 - mean_absolute_error: 0.0952 - mean_absolute_percentage_error: 208.9662 - mean_squared_error: 0.0338 - r2_score: 0.9675 - val_loss: 0.5220 - val_mean_absolute_error: 0.3595 - val_mean_absolute_percentage_error: 585.3939 - val_mean_squared_error: 0.5220 - val_r2_score: 0.3171
# Epoch 87/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0329 - mean_absolute_error: 0.1006 - mean_absolute_percentage_error: 247.2788 - mean_squared_error: 0.0329 - r2_score: 0.9694 - val_loss: 0.5222 - val_mean_absolute_error: 0.3546 - val_mean_absolute_percentage_error: 564.4452 - val_mean_squared_error: 0.5222 - val_r2_score: 0.3168
# Epoch 88/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0317 - mean_absolute_error: 0.0941 - mean_absolute_percentage_error: 170.7510 - mean_squared_error: 0.0317 - r2_score: 0.9693 - val_loss: 0.5361 - val_mean_absolute_error: 0.3730 - val_mean_absolute_percentage_error: 529.0288 - val_mean_squared_error: 0.5361 - val_r2_score: 0.2986
# Epoch 89/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0248 - mean_absolute_error: 0.0873 - mean_absolute_percentage_error: 268.1753 - mean_squared_error: 0.0248 - r2_score: 0.9734 - val_loss: 0.5238 - val_mean_absolute_error: 0.3766 - val_mean_absolute_percentage_error: 462.2869 - val_mean_squared_error: 0.5238 - val_r2_score: 0.3148
# Epoch 90/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0424 - mean_absolute_error: 0.1140 - mean_absolute_percentage_error: 262.0332 - mean_squared_error: 0.0424 - r2_score: 0.9525 - val_loss: 0.5299 - val_mean_absolute_error: 0.3683 - val_mean_absolute_percentage_error: 482.3290 - val_mean_squared_error: 0.5299 - val_r2_score: 0.3068
# Epoch 91/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0290 - mean_absolute_error: 0.0957 - mean_absolute_percentage_error: 195.1706 - mean_squared_error: 0.0290 - r2_score: 0.9729 - val_loss: 0.5392 - val_mean_absolute_error: 0.3658 - val_mean_absolute_percentage_error: 489.8969 - val_mean_squared_error: 0.5392 - val_r2_score: 0.2946
# Epoch 92/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0270 - mean_absolute_error: 0.0876 - mean_absolute_percentage_error: 214.0196 - mean_squared_error: 0.0270 - r2_score: 0.9708 - val_loss: 0.5237 - val_mean_absolute_error: 0.3684 - val_mean_absolute_percentage_error: 508.8762 - val_mean_squared_error: 0.5237 - val_r2_score: 0.3149
# Epoch 93/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0326 - mean_absolute_error: 0.0956 - mean_absolute_percentage_error: 178.1810 - mean_squared_error: 0.0326 - r2_score: 0.9675 - val_loss: 0.5236 - val_mean_absolute_error: 0.3618 - val_mean_absolute_percentage_error: 485.9475 - val_mean_squared_error: 0.5236 - val_r2_score: 0.3150
# Epoch 94/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0311 - mean_absolute_error: 0.0978 - mean_absolute_percentage_error: 243.5885 - mean_squared_error: 0.0311 - r2_score: 0.9650 - val_loss: 0.5310 - val_mean_absolute_error: 0.3710 - val_mean_absolute_percentage_error: 512.0995 - val_mean_squared_error: 0.5310 - val_r2_score: 0.3054
# Epoch 95/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0321 - mean_absolute_error: 0.1012 - mean_absolute_percentage_error: 186.1251 - mean_squared_error: 0.0321 - r2_score: 0.9619 - val_loss: 0.5245 - val_mean_absolute_error: 0.3589 - val_mean_absolute_percentage_error: 556.0897 - val_mean_squared_error: 0.5245 - val_r2_score: 0.3138
# Epoch 96/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0551 - mean_absolute_error: 0.1199 - mean_absolute_percentage_error: 172.1761 - mean_squared_error: 0.0551 - r2_score: 0.9475 - val_loss: 0.5090 - val_mean_absolute_error: 0.3580 - val_mean_absolute_percentage_error: 543.8014 - val_mean_squared_error: 0.5090 - val_r2_score: 0.3341
# Epoch 97/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0372 - mean_absolute_error: 0.1065 - mean_absolute_percentage_error: 227.1948 - mean_squared_error: 0.0372 - r2_score: 0.9592 - val_loss: 0.5686 - val_mean_absolute_error: 0.3905 - val_mean_absolute_percentage_error: 494.6683 - val_mean_squared_error: 0.5686 - val_r2_score: 0.2562
# Epoch 98/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0574 - mean_absolute_error: 0.1246 - mean_absolute_percentage_error: 299.4401 - mean_squared_error: 0.0574 - r2_score: 0.9461 - val_loss: 0.5415 - val_mean_absolute_error: 0.3638 - val_mean_absolute_percentage_error: 568.9108 - val_mean_squared_error: 0.5415 - val_r2_score: 0.2915
# Epoch 99/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0402 - mean_absolute_error: 0.1099 - mean_absolute_percentage_error: 222.1828 - mean_squared_error: 0.0402 - r2_score: 0.9576 - val_loss: 0.5151 - val_mean_absolute_error: 0.3628 - val_mean_absolute_percentage_error: 511.8596 - val_mean_squared_error: 0.5151 - val_r2_score: 0.3262
# Epoch 100/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0345 - mean_absolute_error: 0.1042 - mean_absolute_percentage_error: 217.6355 - mean_squared_error: 0.0345 - r2_score: 0.9599 - val_loss: 0.4984 - val_mean_absolute_error: 0.3582 - val_mean_absolute_percentage_error: 496.1146 - val_mean_squared_error: 0.4984 - val_r2_score: 0.3479
# 25/25 - 0s - 6ms/step - loss: 0.6897 - mean_absolute_error: 0.4535 - mean_absolute_percentage_error: 342.2391 - mean_squared_error: 0.6897 - r2_score: 0.4103

# %%
mlflow.end_run()
